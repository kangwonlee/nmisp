# %% [markdown]
# <a href="https://colab.research.google.com/github/kangwonlee/nmisp/blob/lecture-idea/60_linear_algebra_2/110_Beam_Reaction_Force.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 그래프, 수학 기능 추가
# Add graph and math features
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as nl

# %% [markdown]
# 참고문헌 : Pytel 외 저, 이주성 외 역, 재료역학, 2판, 한티미디어, 2013.<br>Ref: Pytel, Kiusalaas, Sharma, Mechanics of Materials, 2nd Ed., Cengage Learning, 2013.

# %% [markdown]
# 다음과 같은 보의 반력을 구해 보자.<br>
# Let's try to find the reaction forces of the following beam.

# %% [markdown]
# 길이 $L=7 m$<br>Length $L=7 m$

# %%
L_m = 7

# %% [markdown]
# 양단 단순 지지<br>Simple supports at both ends

# %% [markdown]
# 왼쪽 끝에서 $x_1 = 2 m$ 지점에 $F_1 = 14 kN$ 하중<br>
# $F_1 = 14 kN$ load at $x_1 = 2 m$ from the left end

# %%
x_1_m = 2
F_1_N = 14e3

# %% [markdown]
# 왼쪽 끝에서 $x_2 = 5 m$ 지점에 $F_2 = 28 kN$ 하중<br>
# $F_2 = 28 kN$ load at $x_2 = 5 m$ from the left end

# %%
x_2_m = 5
F_2_N = 28e3

# %%
thickness = 0.2

x = (0, L_m)
y = (thickness, thickness)
plt.fill_between(x, y)

plt.quiver(
    (0, x_1_m, x_2_m, L_m),
    (-1, 1+thickness, 1+thickness, -1),
    (0, 0, 0, 0),
    (1, -1, -1, 1),
    scale_units='xy',
    scale=1.0
)

plt.text(0, -1, '$R_1$')
plt.text(L_m, -1, '$R_2$')

plt.text(x_1_m, -1, '$R_1$')
plt.text(L_m, -1, '$R_2$')

plt.axis('equal')

plt.grid(True)
plt.show()

# %% [markdown]
# $y$ 방향 힘의 평형<br>Force equilibrium in $y$ direction

# %% [markdown]
# $$
# R_1 + R_2 = F_1 + F_2
# $$

# %% [markdown]
# $x_1=2m$ 지점에서의 모멘트 평형

# %% [markdown]
# $$
# -x_1R_1 + \left(L-x_1 \right) R_2 = \left(x_2 - x_1\right) F_2
# $$

# %% [markdown]
# 행렬 형태로는 다음과 같다.<br>In matrix form:

# %% [markdown]
# $$
# \begin{bmatrix}
# 1 & 1 \\
# -x_1 & L-x_1 \\
# \end{bmatrix}
# \begin{pmatrix}
# R_1 \\
# R_2 \\
# \end{pmatrix}
# =
# \begin{pmatrix}
# F_1 + F_2 \\
# \left(x_2 - x_1\right)F_2 \\
# \end{pmatrix}
# $$

# %% [markdown]
# 따라서 계수 행렬과 상수항 열 벡터는 각각 다음과 같다.<br>
# Thus coefficient matrix and the column vector of constant terms are as follows, respectively. (https://en.wikipedia.org/wiki/Coefficient_matrix)

# %%
A = np.array([[1, 1],
              [-x_1_m, L_m - x_1_m]])

# %%
b = np.array([[F_1_N + F_2_N],
              [(x_2_m - x_1_m)*F_2_N]])

# %% [markdown]
# 위 방정식의 해는 다음과 같이 구할 수 있다.<br>
# We can find the solution of the equation above as follows.

# %%
nl.solve(A, b)

# %% [markdown]
# 첫 행의 값은 $R_1$, 두번째 행의 값은 $R_2$이다.<br>
# The values of the first and second row are $R_1$ and $R_2$ respectively.

# %% [markdown]
# ## Final Bell<br>마지막 종

# %%
# stackoverfow.com/a/24634221
import os
os.system("printf '\a'");
