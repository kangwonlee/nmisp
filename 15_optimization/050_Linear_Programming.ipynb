# %% [markdown]
# <a href="https://colab.research.google.com/github/kangwonlee/nmisp/blob/main/15_optimization/050_Linear_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Programming<br>선형계획법

# %% [markdown]
# > _Explanation added by Claude (Anthropic) — beginner-friendly notes._
# > _이하 설명은 Claude (Anthropic) 가 초보자용으로 추가한 것입니다._
#
# **What makes Linear Programming (LP) special · 선형계획법(LP)의 특별한 점**
#
# LP is a very restricted — but very useful — form of optimization:
# LP 는 매우 제한적이지만 매우 유용한 형태의 최적화다:
#
# - The **objective function** is a linear combination of variables: $c_1 x_1 + c_2 x_2 + \ldots$.
#   **목적함수** 가 변수들의 선형 결합: $c_1 x_1 + c_2 x_2 + \ldots$.
# - All **constraints** are linear inequalities or equalities.
#   모든 **제약조건** 이 선형 부등식/등식.
#
# Why this restriction matters: because both objective and constraints are linear, the **feasible region** (the set of points satisfying all constraints) is a **convex polytope** (a polygon in 2D, a polyhedron in 3D). The optimum, if it exists, always sits at a **vertex** of this polytope.
# 왜 중요한가: 목적과 제약이 모두 선형이므로 **실행가능 영역** (제약을 모두 만족하는 점들의 집합) 은 **볼록 다면체** (2D에서는 다각형, 3D에서는 다면체) 가 된다. 최적해는 존재한다면 반드시 이 다면체의 **꼭짓점** 에 있다.
#
# That fact makes LP **fast to solve** — algorithms like Simplex just walk from vertex to vertex. Modern solvers handle millions of variables routinely. Real-world uses: production planning, logistics, diet optimization, portfolio allocation, etc.
# 이 성질 덕분에 LP 는 **매우 빨리** 풀린다 — Simplex 알고리듬은 꼭짓점을 따라 이동한다. 현대 solver 는 수백만 변수도 거뜬하다. 실제 용도: 생산 계획, 물류, 식단 최적화, 포트폴리오 배분 등.
#
# This notebook uses a farm-planning example: decide how much area to allocate to wheat vs rice, given fertilizer/pesticide limits.
# 이 노트북은 농장 계획 예제를 쓴다: 비료·살충제 제약 하에서 밀과 쌀의 재배 면적을 정하는 문제.

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as nl
import scipy.optimize as so

# %%
# to save CI time

import os
if os.getenv('CI', False):
    options = {'maxiter': 10}
else:
    options = None

# %% [markdown]
# ref :
# * Wikipedia [link](https://en.wikipedia.org/wiki/Linear_programming)
# * Stackoverflow [link](https://stackoverflow.com/questions/62571092/)
# * Tips & Tricks on Linux, Matlab, vim, LaTex, etc [link](http://tipstrickshowtos.blogspot.com/2012/04/how-to-render-argmax-argmin-operator-in.html)

# %% [markdown]
# ## Problem description<br>문제 설명

# %% [markdown]
# * Area of the farm 농장의 넓이 : $L = 10 (km^2)$
# * Types of crops : wheat or rice<br>작물의 종류 : 밀 또는 쌀
# * Available fertilizer 사용 가능한 비료의 양 : $F = 10 (kg)$
# * Available pesticide 사용 가능한 살충제의 양 : $P = 5 (kg)$

# %% [markdown]
# |   | Wheat 밀 | rice 쌀 |
# |:-----:|:-----:|:-----:|
# | Needed Fertilizer per unit area $(kg/km^2)$<br>단위면적 당 필요 비료 양 $(kg/km^2)$ | $F_1$ | $F_2$ |
# | Needed Pesticide per unit area $(kg/km^2)$<br>단위면적 당 필요 살충제 양 $(kg/km^2)$ | $P_1$ | $P_2$ |
# | Selling price per unit area $(\$/km^2)$<br>단위면적 당 매출 $(\$/km^2)$ | $S_1$ | $S_2$ |
# | Planting area $(km^2)$<br>재배 면적 $(km^2)$ | $x_1$ | $x_2$ |

# %% [markdown]
# * Under the constraints, what are the areas of wheat and rice maximizing the overall selling price?<br>제한조건 하에서 매출을 최대로 하는 밀과 쌀의 재배 면적?

# %% [markdown]
# $$
# \underset{x_1, x_2}{\arg\max} \left(S_1 x_1 + S_2 x_2\right)
# $$

# %% [markdown]
# subject to 제한조건

# %% [markdown]
# $$
# \begin{align}
#     x_1 + x_2 & \le L \\
#     F_1 x_1 + F_2 x_2 & \le F \\
#     P_1 x_1 + P_2 x_2 & \le P \\
#     x_1, x_2 & \ge 0
# \end{align}
# $$

# %% [markdown]
# In matrix form 행렬 형태로는:

# %% [markdown]
# $$
# \underset{x_1, x_2}{\arg\max} \begin{bmatrix} S_1 & S_2    \end{bmatrix}\begin{pmatrix} x_1 \\ x_2    \end{pmatrix}
# $$

# %% [markdown]
# subject to 제한조건

# %% [markdown]
# $$
# \begin{align}
#     \begin{bmatrix}
#         1 & 1 \\
#         F_1 &  F_2 \\
#         P_1 &  P_2 \\
#     \end{bmatrix}
#     \begin{pmatrix}
#         x_1 \\
#         x_2
#     \end{pmatrix} & \le
#     \begin{pmatrix}
#         L \\
#         F \\
#         P
#     \end{pmatrix} \\
#     \begin{pmatrix}
#         x_1 \\
#         x_2
#     \end{pmatrix}& \ge 0
# \end{align}
# $$

# %% [markdown]
# ## Parameters Example<br>매개변수 예

# %%
L = 10

# %%
F = 10 # 현재 확보된 비료 양
F1 = 2 # 밀 1 평방km 당 소모 비료 양
F2 = 3 # 쌀 1 평방km 당 소모 비료 양

# %%
P = 5  # 현재 확보된 살충제 양
P1 = 2 # 밀 1 평방km 당 소모 살충제 양
P2 = 1 # 쌀 1 평방km 당 소모 살충제 양

# %%
S1 = 20
S2 = 25

# %% [markdown]
# ## Visualization 시각화

# %% [markdown]
# $$
# \begin{align}
#     x_1 + x_2 & \le L \\
#     F_1 x_1 + F_2 x_2 & \le F \\
#     P_1 x_1 + P_2 x_2 & \le P \\
#     x_1, x_2 & \ge 0
# \end{align}
# $$

# %% [markdown]
# $$
# \begin{align}
#     x_2 & \le -x_1 + L \\
#     x_2 & \le -\frac{F_1}{F_2} x_1 + \frac{F}{F_2} \\
#     x_2 & \le -\frac{P_1}{P_2} x_1 + \frac{P}{P_2} \\
#     x_1 & \ge 0 \\
#     x_2 & \ge 0
# \end{align}
# $$

# %%
def f_bound(x):
  return (-F1 * x + F) / F2

def p_bound(x):
  return (-P1 * x + P) / P2

# %%
x1 = np.linspace(0, 2.5, 101)
x2 = np.linspace(0, 5, 101)

X1, X2 = np.meshgrid(x1, x2)

C = S1 * X1 + S2 * X2

# indicate regions beyond F & B bounds
C[X2 > f_bound(X1)] = np.nan
C[X2 > p_bound(X1)] = np.nan

plt.pcolor(X1, X2, C, shading="auto")

plt.plot(x1, f_bound(x1), label='F')
plt.plot(x1, p_bound(x1), label='P')

plt.xlabel("$x_1$")
plt.ylabel("$x_2$")

plt.legend(loc=0)
plt.title("$S_1 x_1 + S_2 x_2$")
plt.colorbar()

plt.contour(X1, X2, C, colors='m', linestyles='dashed')

plt.grid(True)

# %% [markdown]
# > _Explanation added by Claude (Anthropic) — beginner-friendly notes._
# > _이하 설명은 Claude (Anthropic) 가 초보자용으로 추가한 것입니다._
#
# **`linprog` standard form · `linprog` 표준형**
#
# SciPy's `linprog` **minimizes** the objective. But our problem **maximizes** revenue. Fix: negate the objective.
# SciPy 의 `linprog` 는 목적함수를 **최소화**한다. 그러나 이 문제는 매출 **최대화**. 해결: 목적함수에 음수를 곱한다.
#
# $$
# \max (S_1 x_1 + S_2 x_2) = -\min (-S_1 x_1 - S_2 x_2)
# $$
#
# Hence the next cell's `c_T = -np.array((S1, S2))`.
# 그래서 다음 셀은 `c_T = -np.array((S1, S2))`.
#
# The standard form `linprog` expects:
# `linprog` 가 기대하는 표준형:
#
# $$
# \min_{\mathbf{x}} \mathbf{c}^\top \mathbf{x} \quad \text{subject to} \quad A_{ub} \mathbf{x} \le \mathbf{b}_{ub}, \quad A_{eq} \mathbf{x} = \mathbf{b}_{eq}, \quad \ell \le \mathbf{x} \le \mathbf{u}
# $$
#
# | SciPy argument | Meaning · 의미 |
# |---|---|
# | `c` | Objective coefficients (we pass `c_T`, i.e., $-\mathbf{S}$). 목적함수 계수 (여기서는 $-\mathbf{S}$). |
# | `A_ub, b_ub` | Inequality constraints $A_{ub} \mathbf{x} \le \mathbf{b}_{ub}$. 부등식 제약. |
# | `A_eq, b_eq` | Equality constraints (unused here). 등식 제약 (여기서는 미사용). |
# | `bounds` | Per-variable box limits $[\ell_i, u_i]$. 변수별 상하한. |

# %% [markdown]
# ## `scipy.optimize.linprog()`

# %%
c_T = -np.array((S1, S2))

# %%
A_ub = np.array(
    (
        (1, 1),
        (F1, F2),
        (P1, P2),
    )
)

# %%
b_ub = np.array(
    ((L, F, P),)
).T

# %% [markdown]
# Here, `.T` indicates transpose.<br>
# 여기서 `.T` 는 행과 열을 바꾸는 transpose

# %% [markdown]
# Bounds for $x_1$, $x_2$<br>
# $x_1$, $x_2$ 의 범위

# %%
bounds = (
    (0, 10),
    (0, 10),
)

# %%
result = so.linprog(
    c_T, A_ub, b_ub,
    bounds=bounds,
    options=options,
)
result

# %% [markdown]
# > _Explanation added by Claude (Anthropic) — beginner-friendly notes._
# > _이하 설명은 Claude (Anthropic) 가 초보자용으로 추가한 것입니다._
#
# **Reading the result · 결과 읽기**
#
# `result.x` gives the optimal $(x_1, x_2)$ — the areas for wheat and rice. `result.fun` is the **minimized** value of $\mathbf{c}^\top \mathbf{x}$, so the actual maximum revenue is `-result.fun` (undo the sign flip).
# `result.x` 는 최적 $(x_1, x_2)$ — 밀과 쌀 면적. `result.fun` 은 **최소화** 된 $\mathbf{c}^\top \mathbf{x}$ 값이므로, 실제 최대 매출은 `-result.fun` (부호 뒤집기를 되돌림).
#
# `result.status == 0` and `result.success == True` mean the solver converged to a feasible optimum. Other statuses:
# `result.status == 0` 그리고 `result.success == True` 이면 실행가능 최적해 수렴. 기타 상태:
# - `1`: iteration limit reached. 반복 한도 도달.
# - `2`: problem **infeasible** (no point satisfies all constraints). 실행 불가능 (제약을 만족하는 점 없음).
# - `3`: problem **unbounded** (objective can be improved without limit). 무계 (목적함수가 한없이 좋아짐).
#
# In the plot below, the optimum should lie at a **vertex** of the feasible region (the polygon formed by constraint lines and the axes) — exactly as LP theory predicts.
# 아래 그래프에서 최적점은 실행가능 영역(제약선들과 축이 이루는 다각형)의 **꼭짓점** 에 있어야 한다 — LP 이론이 예측하는 그대로.
#
# **Try this · 해보기**: change `F`, `P`, or prices `S1`, `S2` and re-run. The optimal vertex may jump from one corner to another — a property called **sensitivity**, important in real applications where inputs have uncertainty.
# **시도해 보기**: `F`, `P`, 혹은 가격 `S1`, `S2` 를 바꾸고 다시 실행하라. 최적 꼭짓점이 한 모서리에서 다른 모서리로 "튀는" 것을 볼 수 있다 — 이를 **민감도(sensitivity)** 라 하며, 입력에 불확실성이 있는 실제 응용에서 중요하다.

# %%
x1 = np.linspace(0, 2.5, 101)
x2 = np.linspace(0, 5, 101)

X1, X2 = np.meshgrid(x1, x2)

C = S1 * X1 + S2 * X2

# indicate regions beyond F & B bounds
C[X2 > f_bound(X1)] = np.nan
C[X2 > p_bound(X1)] = np.nan

plt.pcolor(X1, X2, C, shading="auto")


plt.plot(x1, f_bound(x1), label='F')
plt.plot(x1, p_bound(x1), label='P')

plt.plot(result.x[0], result.x[1], 'ro', label='Optimal')

plt.xlabel("$x_1$")
plt.ylabel("$x_2$")

plt.legend(loc=0)
plt.title("$S_1 x_1 + S_2 x_2$")
plt.colorbar()

plt.contour(X1, X2, C, colors='m', linestyles='dashed')

plt.grid(True)
